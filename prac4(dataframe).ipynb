# %%
import pandas as pd
import numpy as np

# Simple data with missing values
data = {
    "Energy Source": ["Solar", "Wind", "Hydropower", "Geothermal", "Biomass", "Nuclear"],
    "Energy Consumption (MWh)": [1200, np.nan, 2900, np.nan, 2500, 3200],
    "Cost (Million $)": [200, 400, np.nan, 150, 250, np.nan]
}

#Create a Dataframe
energy_df = pd.DataFrame(data)
print(energy_df)

#Remove the code with missing values


cleaned_df = energy_df.dropna(axis=0)

print("\nData After Removing Rows with missing Values")
print(cleaned_df)
# Out:
#   Energy Source  Energy Consumption (MWh)  Cost (Million $)
# 0         Solar                    1200.0             200.0
# 1          Wind                       NaN             400.0
# 2    Hydropower                    2900.0               NaN
# 3    Geothermal                       NaN             150.0
# 4       Biomass                    2500.0             250.0
# 5       Nuclear                    3200.0               NaN
#
# Data After Removing Rows with missing Values
#   Energy Source  Energy Consumption (MWh)  Cost (Million $)
# 0         Solar                    1200.0             200.0
# 4       Biomass                    2500.0             250.0

# %%
import pandas as pd
import numpy as np

#sample data with missing values

data={
    "Energy source": ["solar", "wind", "hydro", "geothermal", "biomass", "tidal"],
    "Energy comsumption (MWh)": [1200, np.nan, 2900, np.nan,2500,3200],
    "cost(Million $)": [200,400, np.nan, 150,250,np.nan]
}

#Create a DataFrame
energy_df = pd.DataFrame(data)
print("Initial Energy DataFrame with Missing Values:")
print(energy_df)

#remove row with any missing values
cleaned_df = energy_df.dropna(axis=0)

print("\nCleaned Energy DataFrame (Rows with Missing Values Removed):")
print(cleaned_df)


#Fill missing values with mean

ec_mean = energy_df["Energy comsumption (MWh)"].mean()
cost_mean = energy_df["cost(Million $)"].mean() 
print(f"\nMean Energy Consumption (MWh): {ec_mean}")
print(f"Mean Cost (Million $): {cost_mean}")    


#Impute missing values in energy Consumption(MWh) with mean

energy_df["Energy comsumption (MWh)"] = energy_df["Energy comsumption (MWh)"].fillna(ec_mean)

#Impute missing values in cost(Million $) with mean
energy_df["cost(Million $)"] = energy_df["cost(Million $)"].fillna(cost_mean)

print("\nEnergy DataFrame after Imputing Missing Values with Mean:")
energy_df.head()
print(energy_df)

#forward data filling
energy_df_ffill = energy_df.copy()
energy_df_ffill["Energy comsumption (MWh)"] = energy_df_ffill["Energy comsumption (MWh)"].ffill()
energy_df_ffill["cost(Million $)"] = energy_df_ffill["cost(Million $)"].ffill()
print("\nEnergy DataFrame after Forward Fill Imputation:")
print(energy_df_ffill)

#backward data filling
energy_df_bfill = energy_df.copy()
energy_df_bfill["Energy comsumption (MWh)"] = energy_df_bfill["Energy comsumption (MWh)"].bfill()
energy_df_bfill["cost(Million $)"] = energy_df_bfill["cost(Million $)"].bfill()
print("\nEnergy DataFrame after Backward Fill Imputation:")
print(energy_df_bfill)

from sklearn.preprocessing import MinMaxScaler

# Initialize scaler
scaler = MinMaxScaler()

# Apply Min-Max Scaling to numeric columns
energy_df[["Energy comsumption (MWh)", "cost(Million $)"]] = scaler.fit_transform(
    energy_df[["Energy comsumption (MWh)", "cost(Million $)"]]
)

print("\nData After Normalization (Min-Max Scaling):")
print(energy_df)

from sklearn.preprocessing import StandardScaler


# Initialize scaler
scaler = StandardScaler()

# Apply Standard Scaling to numeric columns
energy_df[["Energy comsumption (MWh)", "cost(Million $)"]] = scaler.fit_transform(
    energy_df[["Energy comsumption (MWh)", "cost(Million $)"]]
)

print("\nData After Normalization (Stndard Scaling):")
print(energy_df)

# Encoding Categorical Variable
# One-hot encode the 'Energy source' column

energy_encoded_df = pd.get_dummies(energy_df, columns=["Energy source"])

print("\nData After One-hot Encoding Categorical Variables:")
print(energy_encoded_df)
# Out:
# Initial Energy DataFrame with Missing Values:
#   Energy source  Energy comsumption (MWh)  cost(Million $)
# 0         solar                    1200.0            200.0
# 1          wind                       NaN            400.0
# 2         hydro                    2900.0              NaN
# 3    geothermal                       NaN            150.0
# 4       biomass                    2500.0            250.0
# 5         tidal                    3200.0              NaN
#
# Cleaned Energy DataFrame (Rows with Missing Values Removed):
#   Energy source  Energy comsumption (MWh)  cost(Million $)
# 0         solar                    1200.0            200.0
# 4       biomass                    2500.0            250.0
#
# Mean Energy Consumption (MWh): 2450.0
# Mean Cost (Million $): 250.0
#
# Energy DataFrame after Imputing Missing Values with Mean:
#   Energy source  Energy comsumption (MWh)  cost(Million $)
# 0         solar                    1200.0            200.0
# ...

# %%
species_counts = df['species'].value_counts()

plt.figure()
plt.pie(species_counts, labels=species_counts.index, autopct='%1.1f%%')
plt.title("Species Distribution")
plt.show()

avg_sepal_length = df.groupby('species')['sepal_length'].mean()

plt.figure()
avg_sepal_length.plot(kind='bar')
plt.title("Average Sepal Length per Species")
plt.xlabel("Species")
plt.ylabel("Sepal Length")
plt.show()

plt.figure()
plt.hist(df['sepal_length'], bins=10)
plt.title("Sepal Length Distribution")
plt.xlabel("Sepal Length")
plt.ylabel("Frequency")
plt.show()

plt.figure()
plt.scatter(df['sepal_length'], df['petal_length'])
plt.title("Sepal Length vs Petal Length")
plt.xlabel("Sepal Length")
plt.ylabel("Petal Length")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 species_counts = df['species'].value_counts()
#       3 plt.figure()
#       4 plt.pie(species_counts, labels=species_counts.index, autopct='%1.1f%%')
#
# NameError: name 'df' is not defined
